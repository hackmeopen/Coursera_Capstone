# %% [markdown]
# # Coursera Capstone Project

# %% [markdown]
# ## Comparing Chicago and New York City

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import lxml.html as lf

from bs4 import BeautifulSoup

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Get the data for New York and put it into a dataframe.

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
#Load the json data
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

#put it in an array    
ny_neighborhoods_data = newyork_data['features']

# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
ny_neighborhoods = pd.DataFrame(columns=column_names)

#Loop through the array
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    ny_neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

#Let's see the dataframe
ny_neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %% [markdown]
# Make sure the dataframe is the right size. It should have 5 boroughs and 306 neighborhoods.

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %% [markdown]
# Visualize the New York neighborhoods.

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
ny_latitude = location.latitude
ny_longitude = location.longitude

# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[ny_latitude, ny_longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Now scrape the Chicago data.

# %%
#The website we are scraping
url=requests.get('https://en.wikipedia.org/wiki/List_of_neighborhoods_in_Chicago').text

#Load the website
soup = BeautifulSoup(url,'lxml')

#Find the table
My_table = soup.find('table',{'class':'wikitable sortable'})

#Get it into a CSV
table1=""
for tr in My_table.find_all('tr'):
    row1=""
    tds = tr.find_next('td').get_text(strip=True)
    row1=row1+","+tds
    tds = tr.find_next('td').get_text(strip=True)
    row1=row1+","+tds
    row1=row1+'\n'
    table1=table1+row1[1:]

#Load it as a CSV
file=open("chicago.csv","wb")
#file.write(bytes(headers,encoding="ascii",errors="ignore"))
file.write(bytes(table1,encoding="ascii",errors="ignore"))

print("File Written!")
# Out:
# File Written!

# %%
#Put it into a dataframe
chicago_df = pd.read_csv('chicago.csv', header=None)
chicago_df.columns=["Neighborhood","Community area"]
chicago_df.drop_duplicates(subset=None, keep='first', inplace=True)
chicago_df.reset_index(inplace=True, drop=True)
chicago_df
# Out:
#                            Neighborhood                      Community area
# 0                           Albany Park                         Albany Park
# 1                       Altgeld Gardens                     Altgeld Gardens
# 2                         Andersonville                       Andersonville
# 3                        Archer Heights                      Archer Heights
# 4                         Armour Square                       Armour Square
# 5                               Ashburn                             Ashburn
# 6                       Ashburn Estates                     Ashburn Estates
# 7                        Auburn Gresham                      Auburn Gresham
# 8                           Avalon Park                         Avalon Park
# 9                              Avondale                            Avondale
# 10                     Avondale Gardens                    Avondale Gardens
# 11                    Back of the Yards                   Back of the Yards
# 12                      Belmont Central                     Belmont Central
# 13                      Belmont Gardens                     Belmont Gardens
# 14                      Belmont Heights                     Belmont Heights
# 15                      Belmont Terrace                     Belmont Terrace
# 16                              Beverly                             Beverly
# 17                         Beverly View                        Beverly View
# 18                        Beverly Woods                       Beverly Woods
# 19                             Big Oaks                            Big Oaks
# 20                             Boystown                            Boystown
# 21                          Bowmanville                         Bowmanville
# 22                             Brainerd                            Brainerd
# 23                            Brickyard                           Brickyard
# 24                           Bridgeport                          Bridgeport
# 25                        Brighton Park                       Brighton Park
# 26                          Bronzeville                         Bronzeville
# 27                             Bucktown                            Bucktown
# 28                        Budlong Woods                       Budlong Woods
# 29                           Buena Park                          Buena Park
# 30                             Burnside                            Burnside
# 31                         CabriniGreen                        CabriniGreen
# 32                      Calumet Heights                     Calumet Heights
# 33                          Canaryville                         Canaryville
# 34                      Central Station                     Central Station
# 35                              Chatham                             Chatham
# 36                         Chicago Lawn                        Chicago Lawn
# 37                            Chinatown                           Chinatown
# 38                     Chrysler Village                    Chrysler Village
# 39                       Clarendon Park                      Clarendon Park
# 40                        Clearing East                       Clearing East
# 41                        Clearing West                       Clearing West
# 42                Cottage Grove Heights               Cottage Grove Heights
# 43                               Cragin                              Cragin
# 44                            Crestline                           Crestline
# 45                       Dearborn Homes                      Dearborn Homes
# 46                        Dearborn Park                       Dearborn Park
# 47                         Douglas Park                        Douglas Park
# 48                              Dunning                             Dunning
# 49                         East Beverly                        East Beverly
# 50                         East Chatham                        East Chatham
# 51                   East Garfield Park                  East Garfield Park
# 52                       East Hyde Park                      East Hyde Park
# 53                          East Pilsen                         East Pilsen
# 54                            East Side                           East Side
# 55                         East Village                        East Village
# 56                           Eden Green                          Eden Green
# 57                            Edgebrook                           Edgebrook
# 58                            Edgewater                           Edgewater
# 59                      Edgewater Beach                     Edgewater Beach
# 60                       Edgewater Glen                      Edgewater Glen
# 61                          Edison Park                         Edison Park
# 62                            Englewood                           Englewood
# 63                             Fernwood                            Fernwood
# 64                           Fifth City                          Fifth City
# 65                            Ford City                           Ford City
# 66                          Forest Glen                         Forest Glen
# 67                          Fuller Park                         Fuller Park
# 68                Fulton River District               Fulton River District
# 69                            Gage Park                           Gage Park
# 70                             Galewood                            Galewood
# 71                              The Gap                             The Gap
# 72                       Garfield Ridge                      Garfield Ridge
# 73                       Gladstone Park                      Gladstone Park
# 74                           Gold Coast                          Gold Coast
# 75                          Golden Gate                         Golden Gate
# 76                         Goose Island                        Goose Island
# 77                       Graceland West                      Graceland West
# 78                      Grand Boulevard                     Grand Boulevard
# 79                       Grand Crossing                      Grand Crossing
# 80               Greater Grand Crossing              Greater Grand Crossing
# 81                            Greektown                           Greektown
# 82                              Gresham                             Gresham
# 83                       Groveland Park                      Groveland Park
# 84                        Hamilton Park                       Hamilton Park
# 85                          Hanson Park                         Hanson Park
# 86                     Heart of Chicago                    Heart of Chicago
# 87                            Hegewisch                           Hegewisch
# 88                              Hermosa                             Hermosa
# 89                       Hollywood Park                      Hollywood Park
# 90                         Homan Square                        Homan Square
# 91                        Humboldt Park                       Humboldt Park
# 92                            Hyde Park                           Hyde Park
# 93            Illinois Medical District           Illinois Medical District
# 94                          Irving Park                         Irving Park
# 95                         Irving Woods                        Irving Woods
# 96                           The Island                          The Island
# 97                              Jackowo                             Jackowo
# 98               Jackson Park Highlands              Jackson Park Highlands
# 99                       Jefferson Park                      Jefferson Park
# 100                              K-Town                              K-Town
# 101                         Kelvyn Park                         Kelvyn Park
# 102                        Kennedy Park                        Kennedy Park
# 103                          Kensington                          Kensington
# 104                             Kenwood                             Kenwood
# 105                       Kilbourn Park                       Kilbourn Park
# 106                     Kosciuszko Park                     Kosciuszko Park
# 107                        Lake Meadows                        Lake Meadows
# 108                           Lake View                           Lake View
# 109                      Lake View East                      Lake View East
# 110                 Lakewood / Balmoral                 Lakewood / Balmoral
# 111                     LeClaire Courts                     LeClaire Courts
# 112  Legends South(Robert Taylor Homes)  Legends South(Robert Taylor Homes)
# 113                            Lilydale                            Lilydale
# 114                        Lincoln Park                        Lincoln Park
# 115                      Lincoln Square                      Lincoln Square
# 116                    Lithuanian Plaza                    Lithuanian Plaza
# 117                        Little Italy                        Little Italy
# 118                      Little Village                      Little Village
# 119                        Logan Square                        Logan Square
# 120                      Longwood Manor                      Longwood Manor
# 121                            The Loop                            The Loop
# 122                     Lower West Side                     Lower West Side
# 123                              Loyola                              Loyola
# 124                    Magnificent Mile                    Magnificent Mile
# 125                        Margate Park                        Margate Park
# 126                      Marquette Park                      Marquette Park
# 127                     Marshall Square                     Marshall Square
# 128                            Marynook                            Marynook
# 129                             Mayfair                             Mayfair
# 130                       McKinley Park                       McKinley Park
# 131                       Merchant Park                       Merchant Park
# 132                           Montclare                           Montclare
# 133                         Morgan Park                         Morgan Park
# 134                     Mount Greenwood                     Mount Greenwood
# 135                       Museum Campus                       Museum Campus
# 136                        New Eastside                        New Eastside
# 137                     Near North Side                     Near North Side
# 138                      Near West Side                      Near West Side
# 139                       New Chinatown                       New Chinatown
# 140                            New City                            New City
# 141                        Noble Square                        Noble Square
# 142                        North Austin                        North Austin
# 143                        North Center                        North Center
# 144                       North Halsted                       North Halsted
# 145                       North Kenwood                       North Kenwood
# 146                      North Lawndale                      North Lawndale
# 147                       North Mayfair                       North Mayfair
# 148                          North Park                          North Park
# 149                             Nortown                             Nortown
# 150                   Norwood Park East                   Norwood Park East
# 151                   Norwood Park West                   Norwood Park West
# 152                             Oakland                             Oakland
# 153                              O'Hare                              O'Hare
# 154                       Old Edgebrook                       Old Edgebrook
# 155                     Old Irving Park                     Old Irving Park
# 156                         Old Norwood                         Old Norwood
# 157                            Old Town                            Old Town
# 158                   Old Town Triangle                   Old Town Triangle
# 159                         Oriole Park                         Oriole Park
# 160                       Palmer Square                       Palmer Square
# 161                          Park Manor                          Park Manor
# 162                           Park West                           Park West
# 163                            Parkview                            Parkview
# 164                       Peterson Park                       Peterson Park
# 165                           Pill Hill                           Pill Hill
# 166                              Pilsen                              Pilsen
# 167                     Polish Downtown                     Polish Downtown
# 168                      Polish Village                      Polish Village
# 169                        Portage Park                        Portage Park
# 170    Prairie Avenue Historic District    Prairie Avenue Historic District
# 171                      Prairie Shores                      Prairie Shores
# 172                      Princeton Park                      Princeton Park
# 173                       Printer's Row                       Printer's Row
# 174                        Pulaski Park                        Pulaski Park
# 175                             Pullman                             Pullman
# 176                      Ranch Triangle                      Ranch Triangle
# 177                          Ravenswood                          Ravenswood
# 178                  Ravenswood Gardens                  Ravenswood Gardens
# 179                    Ravenswood Manor                    Ravenswood Manor
# 180                         River North                         River North
# 181                          River West                          River West
# 182                        River's Edge                        River's Edge
# 183                           Riverdale                           Riverdale
# 184                         Rogers Park                         Rogers Park
# 185                      Roscoe Village                      Roscoe Village
# 186                            Rosehill                            Rosehill
# 187                            Roseland                            Roseland
# 188                            Rosemoor                            Rosemoor
# 189                         Saint Ben's                         Saint Ben's
# 190                           Sauganash                           Sauganash
# 191                Schorsch Forest View                Schorsch Forest View
# 192                    Schorsch Village                    Schorsch Village
# 193                          Scottsdale                          Scottsdale
# 194                 Sheffield Neighbors                 Sheffield Neighbors
# 195                       Sheridan Park                       Sheridan Park
# 196           Sheridan Station Corridor           Sheridan Station Corridor
# 197                       Sleepy Hollow                       Sleepy Hollow
# 198                          Smith Park                          Smith Park
# 199                        South Austin                        South Austin
# 200                       South Chicago                       South Chicago
# 201                       South Commons                       South Commons
# 202                       South Deering                       South Deering
# 203               South East Ravenswood               South East Ravenswood
# 204                     South Edgebrook                     South Edgebrook
# 205                      South Lawndale                      South Lawndale
# 206                          South Loop                          South Loop
# 207                         South Shore                         South Shore
# 208                    Stateway Gardens                    Stateway Gardens
# 209                   Stony Island Park                   Stony Island Park
# 210                       Streeterville                       Streeterville
# 211                     Talley's Corner                     Talley's Corner
# 212                          Tri-Taylor                          Tri-Taylor
# 213                   Ukrainian Village                   Ukrainian Village
# 214                         Union Ridge                         Union Ridge
# 215                  University Village                  University Village
# 216                              Uptown                              Uptown
# 217                           The Villa                           The Villa
# 218                         Vittum Park                         Vittum Park
# 219                            Wacawowo                            Wacawowo
# 220                  Washington Heights                  Washington Heights
# 221                     Washington Park                     Washington Park
# 222                   Wentworth Gardens                   Wentworth Gardens
# 223                        West Beverly                        West Beverly
# 224                        West Chatham                        West Chatham
# 225                   West Chesterfield                   West Chesterfield
# 226                         West DePaul                         West DePaul
# 227                         West Elsdon                         West Elsdon
# 228                      West Englewood                      West Englewood
# 229                  West Garfield Park                  West Garfield Park
# 230                  West Humboldt Park                  West Humboldt Park
# 231                       West Lakeview                       West Lakeview
# 232                           West Lawn                           West Lawn
# 233                           West Loop                           West Loop
# 234                    West Morgan Park                    West Morgan Park
# 235                        West Pullman                        West Pullman
# 236                          West Ridge                          West Ridge
# 237                    West Rogers Park                    West Rogers Park
# 238                           West Town                           West Town
# 239                       West Woodlawn                       West Woodlawn
# 240                         Wicker Park                         Wicker Park
# 241                            Wildwood                            Wildwood
# 242                            Woodlawn                            Woodlawn
# 243                          Wrightwood                          Wrightwood
# 244                Wrightwood Neighbors                Wrightwood Neighbors
# 245                        Wrigleyville                        Wrigleyville

# %%
chicago_df.shape
# Out:
# (246, 2)

# %% [markdown]
# I found a dataset that contains the longitude and latitude of the neighborhoods in Chicago. The dataset needs a little bit of cleaning because it contains duplications.

# %%
chicago_lat_lon = pd.read_csv('community_to_gps.txt', sep='\t', header = 0)
chicago_lat_lon.head()
# Out:
#    Community Area Community Name   Latitude  Longitude
# 0               1    Rogers Park  42.003801 -87.657651
# 1               1    Rogers Park  42.002439 -87.657809
# 2               1    Rogers Park  41.998390 -87.657676
# 3               1    Rogers Park  42.009069 -87.661341
# 4               1    Rogers Park  42.005680 -87.660129

# %% [markdown]
# Clean up all the duplications.

# %%
chicago_lat_lon.drop_duplicates('Community Name', inplace=True)
chicago_lat_lon.drop(columns = 'Community Area', inplace=True)
chicago_lat_lon.reset_index(inplace=True, drop=True)
chicago_lat_lon.head()
# Out:
#    Community Name   Latitude  Longitude
# 0     Rogers Park  42.003801 -87.657651
# 1      West Ridge  41.992071 -87.675487
# 2          Uptown  41.961609 -87.655370
# 3  Lincoln Square  41.968913 -87.674871
# 4    North Center  41.954342 -87.674439
